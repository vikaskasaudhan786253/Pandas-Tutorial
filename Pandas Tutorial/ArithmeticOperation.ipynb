# %%
import pandas as pd

# %%
var = pd.DataFrame({"A":[1,2,3,4,5],"B":[5,6,7,8,9]})
print(var)
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
# 4  5  9

# %%
var["C"] = var["A"]+var["B"]
print(var)
# Out:
#    A  B   C
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12
# 4  5  9  14

# %%
var["C"] = var["A"]-var["B"]
print(var)
# Out:
#    A  B  C
# 0  1  5 -4
# 1  2  6 -4
# 2  3  7 -4
# 3  4  8 -4
# 4  5  9 -4

# %%
var["C"] = var["A"]*var["B"]
print(var)
# Out:
#    A  B   C
# 0  1  5   5
# 1  2  6  12
# 2  3  7  21
# 3  4  8  32
# 4  5  9  45

# %%
var["C"] = var["A"]/var["B"]
print(var)
# Out:
#    A  B         C
# 0  1  5  0.200000
# 1  2  6  0.333333
# 2  3  7  0.428571
# 3  4  8  0.500000
# 4  5  9  0.555556

# %%
var["C"] = var["A"]%var["B"]
print(var)
# Out:
#    A  B  C
# 0  1  5  1
# 1  2  6  2
# 2  3  7  3
# 3  4  8  4
# 4  5  9  5

# %%
var["C"] = var["A"]**var["B"]
print(var)
# Out:
#    A  B        C
# 0  1  5        1
# 1  2  6       64
# 2  3  7     2187
# 3  4  8    65536
# 4  5  9  1953125

# %%
var["C"] = var["A"]//var["B"]
print(var)
# Out:
#    A  B  C
# 0  1  5  0
# 1  2  6  0
# 2  3  7  0
# 3  4  8  0
# 4  5  9  0

# %%
var1 = pd.DataFrame({"A":[10,20,30,40,50],"B":[15,16,17,81,91]})

var1["Python"] = var1["A"]<=35
var1["Python_1"]=var1["B"]>=15
print(var1)
# Out:
#     A   B  Python  Python_1
# 0  10  15    True      True
# 1  20  16    True      True
# 2  30  17    True      True
# 3  40  81   False      True
# 4  50  91   False      True
