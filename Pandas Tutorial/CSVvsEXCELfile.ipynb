# %% [markdown]
# WRITE CSV

# %%
import pandas as pd

# %%
dic = {"A":[2,3,5,6,7,8],"B":[1,5,8,6,3,2],"C":[12,11,34,56,77,66]}

d = pd.DataFrame(dic)

print(d)

d.to_csv("Text_book1.csv",index=False)
# Out:
#    A  B   C
# 0  2  1  12
# 1  3  5  11
# 2  5  8  34
# 3  6  6  56
# 4  7  3  77
# 5  8  2  66
