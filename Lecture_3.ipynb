# %% [markdown]
# ### More important Functions

# %%
### value_counts
### sort_values
### rank
### sort_index
### set_index
### rename_index -> rename
### reset_indedx
### unique and nunique
### isnull / notnull / hasnans
### dropna
### fillna
### drop_duplicates
### drop
### apply
### isin
### corr
### nlargest -> nsmallest
### insert
### copy

# %%
import numpy as np
import pandas as pd

# %%
# value_counts(series and dataframe)-->frequency count of unique elements

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
## find which player has won most potm -> in final, semi-final, qualifier etc.
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
## Toss and Dicision plot
ipl.head(3)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
toss_dicision = ipl['TossDecision'].value_counts()
toss_dicision
# Out:
# TossDecision
# field    599
# bat      351
# Name: count, dtype: int64

# %%
toss_dicision.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
## how many matches each team played
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
#sort_values(series and dataframe)->ascending->na_position->inplace->multiple cols

# %%
movies = pd.read_csv('movies.csv')
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movies.sort_values('title_x')
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
student = pd.DataFrame({
    'name':['nitish','vikas','ram','shyam',np.nan,'rishabh',np.nan,'rupesh',np.nan,'aditya',np.nan],
    'college':['bit','iit','nit','vit',np.nan,np.nan,'vsli','ssit',np.nan,np.nan,'git'],
    'branch':['eee','cse','cse','me',np.nan,'ce','civ','cse','bio',np.nan,'ece'],
    'package':[6.66,45,23.3,4,np.nan,22,np.nan,9.8,30,11,22],
    'cgpa':[6.66,7.9,9,9.6,np.nan,5.9,7.8,4.6,9.2,np.nan,np.nan]
})
student
# Out:
#        name college branch  package  cgpa
# 0    nitish     bit    eee     6.66  6.66
# 1     vikas     iit    cse    45.00  7.90
# 2       ram     nit    cse    23.30  9.00
# 3     shyam     vit     me     4.00  9.60
# 4       NaN     NaN    NaN      NaN   NaN
# 5   rishabh     NaN     ce    22.00  5.90
# 6       NaN    vsli    civ      NaN  7.80
# 7    rupesh    ssit    cse     9.80  4.60
# 8       NaN     NaN    bio    30.00  9.20
# 9    aditya     NaN    NaN    11.00   NaN
# 10      NaN     git    ece    22.00   NaN

# %%
student.sort_values('name')  ## nan will go down
# Out:
#        name college branch  package  cgpa
# 9    aditya     NaN    NaN    11.00   NaN
# 0    nitish     bit    eee     6.66  6.66
# 2       ram     nit    cse    23.30  9.00
# 5   rishabh     NaN     ce    22.00  5.90
# 7    rupesh    ssit    cse     9.80  4.60
# 3     shyam     vit     me     4.00  9.60
# 1     vikas     iit    cse    45.00  7.90
# 4       NaN     NaN    NaN      NaN   NaN
# 6       NaN    vsli    civ      NaN  7.80
# 8       NaN     NaN    bio    30.00  9.20
# 10      NaN     git    ece    22.00   NaN

# %%
student.sort_values('name',na_position='first')
# Out:
#        name college branch  package  cgpa
# 4       NaN     NaN    NaN      NaN   NaN
# 6       NaN    vsli    civ      NaN  7.80
# 8       NaN     NaN    bio    30.00  9.20
# 10      NaN     git    ece    22.00   NaN
# 9    aditya     NaN    NaN    11.00   NaN
# 0    nitish     bit    eee     6.66  6.66
# 2       ram     nit    cse    23.30  9.00
# 5   rishabh     NaN     ce    22.00  5.90
# 7    rupesh    ssit    cse     9.80  4.60
# 3     shyam     vit     me     4.00  9.60
# 1     vikas     iit    cse    45.00  7.90

# %%
student.sort_values('name',na_position='first',ascending=False)
# Out:
#        name college branch  package  cgpa
# 4       NaN     NaN    NaN      NaN   NaN
# 6       NaN    vsli    civ      NaN  7.80
# 8       NaN     NaN    bio    30.00  9.20
# 10      NaN     git    ece    22.00   NaN
# 1     vikas     iit    cse    45.00  7.90
# 3     shyam     vit     me     4.00  9.60
# 7    rupesh    ssit    cse     9.80  4.60
# 5   rishabh     NaN     ce    22.00  5.90
# 2       ram     nit    cse    23.30  9.00
# 0    nitish     bit    eee     6.66  6.66
# 9    aditya     NaN    NaN    11.00   NaN

# %%
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])[['year_of_release','title_x']]
# Out:
#       year_of_release                               title_x
# 1623             2001                              Zubeidaa
# 1625             2001                  Yeh Zindagi Ka Safar
# 1622             2001         Yeh Teraa Ghar Yeh Meraa Ghar
# 1620             2001              Yeh Raaste Hain Pyaar Ke
# 1573             2001                   Yaadein (2001 film)
# ...               ...                                   ...
# 37               2019                     Article 15 (film)
# 46               2019                         Arjun Patiala
# 10               2019                                Amavas
# 26               2019  Albert Pinto Ko Gussa Kyun Aata Hai?
# 21               2019                              22 Yards
#
# [1629 rows x 2 columns]

# %%
## rank (series)
batsman = pd.read_csv('batsman_runs_ipl.csv')
batsman.sample(5)
# Out:
#               batter  batsman_run
# 82   B Sai Sudharsan          145
# 217    JA Richardson           15
# 211          J Botha          409
# 270        KS Bharat          199
# 570   V Pratap Singh            0

# %%
batsman['batsman_rank'] = batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('batsman_rank')
# Out:
#            batter  batsman_run  batsman_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
## sort_index(series and dataframe)

# %%
marks = {
    'hindi':87,
    'math':98,
    'science':91,
    'english':62
}
marks_series = pd.Series(marks)
marks_series
# Out:
# hindi      87
# math       98
# science    91
# english    62
# dtype: int64

# %%
marks_series.sort_index()
# Out:
# english    62
# hindi      87
# math       98
# science    91
# dtype: int64

# %%
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
## set_index(dataframe) ->inplace 
batsman.set_index('batter',inplace=True)

# %%
batsman.head()
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5

# %%
batsman.reset_index()
# Out:
#              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
## how to raplace index without loosing
batsman.reset_index().set_index('batsman_rank')
# Out:
#                       batter  batsman_run
# batsman_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
## series to dataframe using reset_index
marks_series.reset_index()
# Out:
#      index   0
# 0    hindi  87
# 1     math  98
# 2  science  91
# 3  english  62

# %%
## rename (dataframe) -> index

# %%
movies.set_index('title_x',inplace=True)

# %%
movies
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(columns={'imdb_id':'imdb','poster_path':'link'},inplace=True)

# %%
movies
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.rename(index={'Uri: The Surgical Strike':'Uri','Battalion 609':'Battalion'},inplace=True)

# %%
movies
# Out:
#                                             imdb  \
# title_x
# Uri                                    tt8291224
# Battalion                              tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
## unique (Series)
temp = pd.Series([1,1,1,2,3,2,3,4,3,5,4,np.nan,5,6,np.nan,np.nan,np.nan])
temp
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     2.0
# 4     3.0
# 5     2.0
# 6     3.0
# 7     4.0
# 8     3.0
# 9     5.0
# 10    4.0
# 11    NaN
# 12    5.0
# 13    6.0
# 14    NaN
# 15    NaN
# 16    NaN
# dtype: float64

# %%
temp.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5., nan,  6.])

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
# nunique (series + dataframe) -> does not count nan -> dropna parameter

# %%
len(temp.unique())
# Out:
# 7

# %%
temp.nunique()
# Out:
# 6

# %%
ipl['Season'].nunique()
# Out:
# 15

# %%
### isnull (series and dataframe)
student['name'][student['name'].isnull()]
# Out:
# 4     NaN
# 6     NaN
# 8     NaN
# 10    NaN
# Name: name, dtype: object

# %%
## notnull (series and dataframe)
student['name'][student['name'].notnull()]
# Out:
# 0     nitish
# 1      vikas
# 2        ram
# 3      shyam
# 5    rishabh
# 7     rupesh
# 9     aditya
# Name: name, dtype: object

# %%
## hasnans (series)
student['name'].hasnans
# Out:
# True

# %%
student.isnull()
# Out:
#      name  college  branch  package   cgpa
# 0   False    False   False    False  False
# 1   False    False   False    False  False
# 2   False    False   False    False  False
# 3   False    False   False    False  False
# 4    True     True    True     True   True
# 5   False     True   False    False  False
# 6    True    False   False     True  False
# 7   False    False   False    False  False
# 8    True     True   False    False  False
# 9   False     True    True    False   True
# 10   True    False   False    False   True

# %%
student.notnull()
# Out:
#      name  college  branch  package   cgpa
# 0    True     True    True     True   True
# 1    True     True    True     True   True
# 2    True     True    True     True   True
# 3    True     True    True     True   True
# 4   False    False   False    False  False
# 5    True    False    True     True   True
# 6   False     True    True    False   True
# 7    True     True    True     True   True
# 8   False    False    True     True   True
# 9    True    False   False     True  False
# 10  False     True    True     True  False

# %%
## dropna (series + dataframe)
student['name'].dropna()
# Out:
# 0     nitish
# 1      vikas
# 2        ram
# 3      shyam
# 5    rishabh
# 7     rupesh
# 9     aditya
# Name: name, dtype: object

# %%
student.dropna()
# Out:
#      name college branch  package  cgpa
# 0  nitish     bit    eee     6.66  6.66
# 1   vikas     iit    cse    45.00  7.90
# 2     ram     nit    cse    23.30  9.00
# 3   shyam     vit     me     4.00  9.60
# 7  rupesh    ssit    cse     9.80  4.60

# %%
student.dropna(how='any')
# Out:
#      name college branch  package  cgpa
# 0  nitish     bit    eee     6.66  6.66
# 1   vikas     iit    cse    45.00  7.90
# 2     ram     nit    cse    23.30  9.00
# 3   shyam     vit     me     4.00  9.60
# 7  rupesh    ssit    cse     9.80  4.60

# %%
student.dropna(how='all')
# Out:
#        name college branch  package  cgpa
# 0    nitish     bit    eee     6.66  6.66
# 1     vikas     iit    cse    45.00  7.90
# 2       ram     nit    cse    23.30  9.00
# 3     shyam     vit     me     4.00  9.60
# 5   rishabh     NaN     ce    22.00  5.90
# 6       NaN    vsli    civ      NaN  7.80
# 7    rupesh    ssit    cse     9.80  4.60
# 8       NaN     NaN    bio    30.00  9.20
# 9    aditya     NaN    NaN    11.00   NaN
# 10      NaN     git    ece    22.00   NaN

# %%
student.dropna(subset=['name'])
# Out:
#       name college branch  package  cgpa
# 0   nitish     bit    eee     6.66  6.66
# 1    vikas     iit    cse    45.00  7.90
# 2      ram     nit    cse    23.30  9.00
# 3    shyam     vit     me     4.00  9.60
# 5  rishabh     NaN     ce    22.00  5.90
# 7   rupesh    ssit    cse     9.80  4.60
# 9   aditya     NaN    NaN    11.00   NaN

# %%
student.dropna(subset=['name','college'])
# Out:
#      name college branch  package  cgpa
# 0  nitish     bit    eee     6.66  6.66
# 1   vikas     iit    cse    45.00  7.90
# 2     ram     nit    cse    23.30  9.00
# 3   shyam     vit     me     4.00  9.60
# 7  rupesh    ssit    cse     9.80  4.60

# %%
### fillna (series and dataframe)
student['name'].fillna('unknown')
# Out:
# 0      nitish
# 1       vikas
# 2         ram
# 3       shyam
# 4     unknown
# 5     rishabh
# 6     unknown
# 7      rupesh
# 8     unknown
# 9      aditya
# 10    unknown
# Name: name, dtype: object

# %%
student.fillna({'name':'unknown','college':'unknown','branch':'unknown','package':student['package'].mean(),'cgpa':student['cgpa'].mean()})
# Out:
#        name  college   branch    package    cgpa
# 0    nitish      bit      eee   6.660000  6.6600
# 1     vikas      iit      cse  45.000000  7.9000
# 2       ram      nit      cse  23.300000  9.0000
# 3     shyam      vit       me   4.000000  9.6000
# 4   unknown  unknown  unknown  19.306667  7.5825
# 5   rishabh  unknown       ce  22.000000  5.9000
# 6   unknown     vsli      civ  19.306667  7.8000
# 7    rupesh     ssit      cse   9.800000  4.6000
# 8   unknown  unknown      bio  30.000000  9.2000
# 9    aditya  unknown  unknown  11.000000  7.5825
# 10  unknown      git      ece  22.000000  7.5825

# %%
student['name'].fillna(method='ffill')
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_31868\1485625205.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   student['name'].fillna(method='ffill')
# 0      nitish
# 1       vikas
# 2         ram
# 3       shyam
# 4       shyam
# 5     rishabh
# 6     rishabh
# 7      rupesh
# 8      rupesh
# 9      aditya
# 10     aditya
# Name: name, dtype: object

# %%
student['name'].fillna(method='bfill')
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_31868\792436524.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   student['name'].fillna(method='bfill')
# 0      nitish
# 1       vikas
# 2         ram
# 3       shyam
# 4     rishabh
# 5     rishabh
# 6      rupesh
# 7      rupesh
# 8      aditya
# 9      aditya
# 10        NaN
# Name: name, dtype: object

# %%
student['name'].ffill()
# Out:
# 0      nitish
# 1       vikas
# 2         ram
# 3       shyam
# 4       shyam
# 5     rishabh
# 6     rishabh
# 7      rupesh
# 8      rupesh
# 9      aditya
# 10     aditya
# Name: name, dtype: object

# %%
student['name'].bfill()
# Out:
# 0      nitish
# 1       vikas
# 2         ram
# 3       shyam
# 4     rishabh
# 5     rishabh
# 6      rupesh
# 7      rupesh
# 8      aditya
# 9      aditya
# 10        NaN
# Name: name, dtype: object

# %%
### drop_duplicates(series and dataframe) -> works like and -> duplicated()

# %%
temp = pd.Series([1,1,2,3,2,3,4,5,4,5,6])
temp
# Out:
# 0     1
# 1     1
# 2     2
# 3     3
# 4     2
# 5     3
# 6     4
# 7     5
# 8     4
# 9     5
# 10    6
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0     1
# 2     2
# 3     3
# 6     4
# 7     5
# 10    6
# dtype: int64

# %%
# Out:
# {'hindi': 87, 'math': 98, 'science': 91, 'english': 62}

# %%
marks = pd.DataFrame({
    'iq':[100,90,120,80,80],
    'marks':[80,70,100,70,70],
    'package':[10,7,14,14,14]
})
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.drop_duplicates(keep='last')
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 4   80     70       14

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
## find the last match played by Virat Kohli in delhi
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
def did_kohli_play(player_list):
    return 'V Kohli' in player_list

# %%
did_kohli_play(['V Kohli','MS Dhoni'])
# Out:
# True

# %%
ipl['did_kohli_play'] = ipl['all_players'].apply(did_kohli_play)

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_play'] == True)].drop_duplicates(subset= ['City','did_kohli_play'],keep='last')
# Out:
#          ID   City        Date   Season MatchNumber             Team1  \
# 933  335998  Delhi  2008-04-30  2007/08          17  Delhi Daredevils
#
#                            Team2             Venue  \
# 933  Royal Challengers Bangalore  Feroz Shah Kotla
#
#                       TossWinner TossDecision  ... WonBy Margin method  \
# 933  Royal Challengers Bangalore        field  ...  Runs   10.0    NaN
#
#      Player_of_Match                                       Team1Players  \
# 933       GD McGrath  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'Shoaib ...
#
#                                           Team2Players    Umpire1    Umpire2  \
# 933  ['P Kumar', 'W Jaffer', 'LRPL Taylor', 'JH Kal...  Aleem Dar  I Shivram
#
#                                            all_players did_kohli_play
# 933  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'Shoaib ...           True
#
# [1 rows x 22 columns]

# %%
## drop (series and dataframe)
temp =  pd.Series([1,2,3,22,44,33,5,66])
temp
# Out:
# 0     1
# 1     2
# 2     3
# 3    22
# 4    44
# 5    33
# 6     5
# 7    66
# dtype: int64

# %%
temp.drop(index=[0,2,3])
# Out:
# 1     2
# 4    44
# 5    33
# 6     5
# 7    66
# dtype: int64

# %%
student
# Out:
#        name college branch  package  cgpa
# 0    nitish     bit    eee     6.66  6.66
# 1     vikas     iit    cse    45.00  7.90
# 2       ram     nit    cse    23.30  9.00
# 3     shyam     vit     me     4.00  9.60
# 4       NaN     NaN    NaN      NaN   NaN
# 5   rishabh     NaN     ce    22.00  5.90
# 6       NaN    vsli    civ      NaN  7.80
# 7    rupesh    ssit    cse     9.80  4.60
# 8       NaN     NaN    bio    30.00  9.20
# 9    aditya     NaN    NaN    11.00   NaN
# 10      NaN     git    ece    22.00   NaN

# %%
student.drop(columns=['branch','cgpa'])
# Out:
#        name college  package
# 0    nitish     bit     6.66
# 1     vikas     iit    45.00
# 2       ram     nit    23.30
# 3     shyam     vit     4.00
# 4       NaN     NaN      NaN
# 5   rishabh     NaN    22.00
# 6       NaN    vsli      NaN
# 7    rupesh    ssit     9.80
# 8       NaN     NaN    30.00
# 9    aditya     NaN    11.00
# 10      NaN     git    22.00

# %%
student.drop(index=[0,3,6,7])
# Out:
#        name college branch  package  cgpa
# 1     vikas     iit    cse     45.0   7.9
# 2       ram     nit    cse     23.3   9.0
# 4       NaN     NaN    NaN      NaN   NaN
# 5   rishabh     NaN     ce     22.0   5.9
# 8       NaN     NaN    bio     30.0   9.2
# 9    aditya     NaN    NaN     11.0   NaN
# 10      NaN     git    ece     22.0   NaN

# %%
student.set_index('name').drop(['ram','vikas'])
# Out:
#         college branch  package  cgpa
# name
# nitish      bit    eee     6.66  6.66
# shyam       vit     me     4.00  9.60
# NaN         NaN    NaN      NaN   NaN
# rishabh     NaN     ce    22.00  5.90
# NaN        vsli    civ      NaN  7.80
# rupesh     ssit    cse     9.80  4.60
# NaN         NaN    bio    30.00  9.20
# aditya      NaN    NaN    11.00   NaN
# NaN         git    ece    22.00   NaN

# %%
## apply (series and dataframe)
temp = pd.Series([10,39,40,50,60,70])
temp
# Out:
# 0    10
# 1    39
# 2    40
# 3    50
# 4    60
# 5    70
# dtype: int64

# %%
def sigmoid(value):
    return 1/(1+np.exp(-value))

# %%
temp.apply(sigmoid)
# Out:
# 0    0.999955
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# 5    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame({
    '1st point':[(1,3),(5,7),(-3,5),(5,1)],
    '2nd point':[(6,3),(9,7),(-2,-4),(5,2)]
})
points_df
# Out:
#   1st point 2nd point
# 0    (1, 3)    (6, 3)
# 1    (5, 7)    (9, 7)
# 2   (-3, 5)  (-2, -4)
# 3    (5, 1)    (5, 2)

# %%
def euclidean(row):
    point_A = row['1st point']
    point_B = row['2nd point']
    return ((point_A[0]-point_B[0])**2 + (point_A[1]-point_B[1])**2)**0.5

# %%
points_df['distance']=points_df.apply(euclidean,axis=1)

# %%
points_df
# Out:
#   1st point 2nd point  distance
# 0    (1, 3)    (6, 3)  5.000000
# 1    (5, 7)    (9, 7)  4.000000
# 2   (-3, 5)  (-2, -4)  9.055385
# 3    (5, 1)    (5, 2)  1.000000
